# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\s145n\Documents\Mdoc\D.A\Brasil e-commerce dataset\olist_dataset_da\olist_geolocation_dataset.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000163, step=1)

# %%
df.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %%
df.to_numpy()
# Out:
# array([[1037, -23.54562128115268, -46.63929204800168, 'sao paulo', 'SP'],
#        [1046, -23.54608112703553, -46.64482029837157, 'sao paulo', 'SP'],
#        [1046, -23.54612896641469, -46.64295148361138, 'sao paulo', 'SP'],
#        ...,
#        [99950, -28.07185541645192, -52.01471586864233, 'tapejara', 'RS'],
#        [99980, -28.38893187660049, -51.84687132274168, 'david canabarro',
#         'RS'],
#        [99950, -28.07010363149126, -52.01865772856674, 'tapejara', 'RS']],
#       dtype=object)

# %%
df.dtypes
# Out:
# geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                object
# geolocation_state               object
# dtype: object

# %%
df.shape
# Out:
# (1000163, 5)

# %%
df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
df[1:20] # imprime uma intervalo especifo de linhas. obs: termina em 19 porque começa em 0.
# Out:
#     geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 1                          1046       -23.546081       -46.644820
# 2                          1046       -23.546129       -46.642951
# 3                          1041       -23.544392       -46.639499
# 4                          1035       -23.541578       -46.641607
# 5                          1012       -23.547762       -46.635361
# 6                          1047       -23.546273       -46.641225
# 7                          1013       -23.546923       -46.634264
# 8                          1029       -23.543769       -46.634278
# 9                          1011       -23.547640       -46.636032
# 10                         1013       -23.547325       -46.634184
# 11                         1032       -23.538418       -46.634778
# 12                         1014       -23.546435       -46.633830
# 13                         1012       -23.548946       -46.634671
# ...

# %%
df.tail()
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 1000158         tapejara                RS
# 1000159   getulio vargas                RS
# 1000160         tapejara                RS
# 1000161  david canabarro                RS
# 1000162         tapejara                RS

# %%
df.loc[:,["geolocation_city"]] # imprime os dados da coluna especifica
# Out:
#         geolocation_city
# 0              sao paulo
# 1              sao paulo
# 2              sao paulo
# 3              sao paulo
# 4              sao paulo
# ...                  ...
# 1000158         tapejara
# 1000159   getulio vargas
# 1000160         tapejara
# 1000161  david canabarro
# 1000162         tapejara
#
# [1000163 rows x 1 columns]

# %%
df.loc[:,["geolocation_state"]]
# Out:
#         geolocation_state
# 0                      SP
# 1                      SP
# 2                      SP
# 3                      SP
# 4                      SP
# ...                   ...
# 1000158                RS
# 1000159                RS
# 1000160                RS
# 1000161                RS
# 1000162                RS
#
# [1000163 rows x 1 columns]

# %%
df.sort_values(by='geolocation_city')
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 851430                        81470       -25.571748       -49.334374
# 525385                        28930       -22.969370       -42.029834
# 896733                        87365       -24.271860       -53.069433
# 896977                        87365       -24.281905       -53.074516
# 897217                        87365       -24.277697       -53.074930
# ...                             ...              ...              ...
# 769392                        68250        -1.906782       -55.511308
# 395841                        18790       -22.937454       -49.336995
# 394381                        18790       -22.941366       -49.340714
# 394951                        18790       -22.944293       -49.343426
# 395722                        18790       -22.937775       -49.337569
#
#           geolocation_city geolocation_state
# 851430            * cidade                PR
# ...

# %%
df.loc[:,["geolocation_state","geolocation_city"]]
# Out:
#         geolocation_state geolocation_city
# 0                      SP        sao paulo
# 1                      SP        sao paulo
# 2                      SP        sao paulo
# 3                      SP        sao paulo
# 4                      SP        sao paulo
# ...                   ...              ...
# 1000158                RS         tapejara
# 1000159                RS   getulio vargas
# 1000160                RS         tapejara
# 1000161                RS  david canabarro
# 1000162                RS         tapejara
#
# [1000163 rows x 2 columns]

# %%
df.iloc[0] # Iloc selecuiona uma linha de forma especifica e mostra todos os seus atributos
# Out:
# geolocation_zip_code_prefix         1037
# geolocation_lat               -23.545621
# geolocation_lng               -46.639292
# geolocation_city               sao paulo
# geolocation_state                     SP
# Name: 0, dtype: object

# %%
df.iloc[1000162]
# Out:
# geolocation_zip_code_prefix        99950
# geolocation_lat               -28.070104
# geolocation_lng               -52.018658
# geolocation_city                tapejara
# geolocation_state                     RS
# Name: 1000162, dtype: object

# %%
df.iloc[:,0:3] #imprime as colunas de 0 até 3
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
# [1000163 rows x 3 columns]

# %%
df.iloc[50:100,0:3]
# Out:
#     geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# 50                         1020       -23.552482       -46.629390
# 51                         1047       -23.546605       -46.641982
# 52                         1042       -23.544874       -46.640303
# 53                         1034       -23.542909       -46.636797
# 54                         1047       -23.545999       -46.640835
# 55                         1035       -23.540205       -46.644147
# 56                         1027       -23.538670       -46.629346
# 57                         1046       -23.546382       -46.642894
# 58                         1042       -23.545052       -46.640072
# 59                         1040       -23.540317       -46.637355
# 60                         1046       -23.546397       -46.643059
# 61                         1017       -23.549813       -46.630350
# 62                         1026       -23.539495       -46.632844
# ...

# %%
df.geolocation_state.max()
# Out:
# 'TO'

# %%
df.geolocation_city.max()
# Out:
# 'óleo'

# %%
df['geolocation_city'].value_counts()
# Out:
# sao paulo               135800
# rio de janeiro           62151
# belo horizonte           27805
# são paulo                24918
# curitiba                 16593
#                          ...
# jacuípe                      1
# mar vermelho                 1
# quebrangulo                  1
# poço das trincheiras         1
# poxim                        1
# Name: geolocation_city, Length: 8011, dtype: int64

# %%
df['geolocation_state'].value_counts()
# Out:
# SP    404268
# MG    126336
# RJ    121169
# RS     61851
# PR     57859
# SC     38328
# BA     36045
# GO     20139
# ES     16748
# PE     16432
# DF     12986
# MT     12031
# CE     11674
# PA     10853
# MS     10431
# MA      7853
# PB      5538
# RN      5041
# PI      4549
# AL      4183
# TO      3576
# SE      3563
# RO      3478
# AM      2432
# AC      1301
# AP       853
# RR       646
# Name: geolocation_state, dtype: int64

# %%
df['geolocation_state'].value_counts(normalize=True) #imprime a porcentagem de entradas no df de acordo com o respectivo estado. 
#nesse caso o estado de são paulo está na fernte com 40% de volume de compra.
# Out:
# SP    0.404202
# MG    0.126315
# RJ    0.121149
# RS    0.061841
# PR    0.057850
# SC    0.038322
# BA    0.036039
# GO    0.020136
# ES    0.016745
# PE    0.016429
# DF    0.012984
# MT    0.012029
# CE    0.011672
# PA    0.010851
# MS    0.010429
# MA    0.007852
# PB    0.005537
# RN    0.005040
# PI    0.004548
# AL    0.004182
# TO    0.003575
# SE    0.003562
# RO    0.003477
# AM    0.002432
# AC    0.001301
# AP    0.000853
# RR    0.000646
# Name: geolocation_state, dtype: float64

# %%
df[["geolocation_lat","geolocation_lng"]].apply(lambda x: x.max()) # função utilizada para apresentar máximos valores, apesar de não fazer sentido nesse caso.
# Out:
# geolocation_lat     45.065933
# geolocation_lng    121.105394
# dtype: float64

# %%
df.sort_values(by='geolocation_state',ascending=True) # ordena o df de acordo coma coluna selecionada, nesse caso geolocation_state
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 72852                          4011       -23.578707       -46.645779
# 779054                        69903        -9.932308       -67.810402
# 779053                        69901        -9.985715       -67.815953
# 779052                        69918        -9.933711       -67.817562
# 779051                        69900        -9.975300       -67.809338
# ...                             ...              ...              ...
# 817281                        77390       -11.968961       -48.233587
# 817282                        77320       -12.398432       -46.424827
# 817283                        77325       -12.710646       -46.403401
# 817272                        77330       -12.926296       -46.942630
# 818793                        77760        -8.059166       -48.471988
#
#                  geolocation_city geolocation_state
# 72852                   sao paulo                AC
# ...

# %%
df.sort_values(by='geolocation_city',ascending=True)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 851430                        81470       -25.571748       -49.334374
# 525385                        28930       -22.969370       -42.029834
# 896733                        87365       -24.271860       -53.069433
# 896977                        87365       -24.281905       -53.074516
# 897217                        87365       -24.277697       -53.074930
# ...                             ...              ...              ...
# 769392                        68250        -1.906782       -55.511308
# 395841                        18790       -22.937454       -49.336995
# 394381                        18790       -22.941366       -49.340714
# 394951                        18790       -22.944293       -49.343426
# 395722                        18790       -22.937775       -49.337569
#
#           geolocation_city geolocation_state
# 851430            * cidade                PR
# ...

# %%
df.sort_values(by='geolocation_zip_code_prefix',ascending=True)
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 1246                            1001       -23.549292       -46.633559
# 429                             1001       -23.550498       -46.634338
# 1182                            1001       -23.549779       -46.633957
# 1435                            1001       -23.549292       -46.633559
# 326                             1001       -23.551427       -46.634074
# ...                              ...              ...              ...
# 1000026                        99980       -28.388679       -51.848863
# 999950                         99980       -28.388400       -51.845225
# 1000002                        99980       -28.388342       -51.845194
# 999864                         99990       -28.329472       -51.769109
# 999758                         99990       -28.329718       -51.769615
#
#         geolocation_city geolocation_state
# 1246           sao paulo                SP
# ...

# %%
df.sort_values(by='geolocation_lat',ascending=True)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 992584                        98780       -36.605374       -64.283946
# 993302                        98780       -36.603837       -64.287433
# 993075                        98780       -36.603837       -64.287433
# 695375                        45936       -34.622400       -58.901888
# 513643                        28155       -34.586422       -58.732101
# ...                             ...              ...              ...
# 860562                        83252        42.184003        -8.723762
# 770534                        68447        42.428884        -6.873344
# 513754                        28155        42.439286        13.820214
# 516682                        28595        43.684961        -7.411080
# 727755                        57319        45.065933         9.341528
#
#           geolocation_city geolocation_state
# 992584          santa rosa                RS
# ...

# %%
df.sort_values(by='geolocation_lng',ascending=True)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 538557                        29654        21.657547      -101.466766
# 538512                        29654        29.409252       -98.484121
# 585242                        35179        25.995203       -98.078544
# 585260                        35179        25.995245       -98.078533
# 779240                        69990        -7.597105       -72.930746
# ...                             ...              ...              ...
# 514429                        28333        38.381672        -6.328200
# 697048                        46560        38.991963        -4.947823
# 727755                        57319        45.065933         9.341528
# 513754                        28155        42.439286        13.820214
# 965687                        95130        14.585073       121.105394
#
#               geolocation_city geolocation_state
# 538557  santo antonio do canaa                ES
# ...

# %%
df['geolocation_state'].value_counts().plot(kind='bar') # imprime um gráfico de barras , tornando a visualização dos dados mais prática.
# Out:
# <AxesSubplot:>
