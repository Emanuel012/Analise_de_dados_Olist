# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\s145n\Documents\Mdoc\D.A\Brasil e-commerce dataset\olist_order_items_dataset.csv")

# %%
df.head() # imprime os 5 primeiros valores da lista
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df.index #Imprime informações sobre o dataframe
# Out:
# RangeIndex(start=0, stop=112650, step=1)

# %%
df.columns # imprime as colunas presentes no dataset
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')

# %%
df.to_numpy() # converte o df em uma matriz numpy
# Out:
# array([['00010242fe8c5a6d1ba2dd792cb16214', 1,
#         '4244733e06e7ecb4970a6e2683c13e61', ..., '2017-09-19 09:45:35',
#         58.9, 13.29],
#        ['00018f77f2f0320c557190d7a144bdd3', 1,
#         'e5f2d52b802189ee658865ca93d83a8f', ..., '2017-05-03 11:05:13',
#         239.9, 19.93],
#        ['000229ec398224ef6ca0657da4fc703e', 1,
#         'c777355d18b72b67abbeef9df44fd0fd', ..., '2018-01-18 14:48:30',
#         199.0, 17.87],
#        ...,
#        ['fffce4705a9662cd70adb13d4a31832d', 1,
#         '72a30483855e2eafc67aee5dc2560482', ..., '2017-10-30 17:14:25',
#         99.9, 16.95],
#        ['fffe18544ffabc95dfada21779c9644f', 1,
#         '9c422a519119dcad7575db5af1ba540e', ..., '2017-08-21 00:04:32',
#         55.99, 8.72],
#        ['fffe41c64501cc87c801fd61db3f6244', 1,
#         '350688d9dc1e75ff97be326363655e01', ..., '2018-06-12 17:10:13',
#         43.0, 12.79]], dtype=object)

# %%
df.describe() # descreve os dados do tipo integer , mostrando informações de moda, média e mediana
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
df.dtypes # imprime o tipo de dados presente no dataframe
# Out:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=112650, step=1)

# %%
df.shape # imprime o número de linhas e colunas
# Out:
# (112650, 7)

# %%
df.head(15) # imprime as 15 primeiras linhas do "cabeçalho"
# Out:
#                             order_id  order_item_id  \
# 0   00010242fe8c5a6d1ba2dd792cb16214              1
# 1   00018f77f2f0320c557190d7a144bdd3              1
# 2   000229ec398224ef6ca0657da4fc703e              1
# 3   00024acbcdf0a6daa1e931b038114c75              1
# 4   00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5   00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6   00054e8431b9d7675808bcb819fb4a32              1
# 7   000576fe39319847cbb9d288c5617fa6              1
# 8   0005a1a1728c9d785b8e2b08b904576c              1
# 9   0005f50442cb953dcd1d21e1fb923495              1
# 10  00061f2a7bc09da83e415a52dc8a4af1              1
# 11  00063b381e2406b52ad429470734ebd5              1
# 12  0006ec9db01a64e59a68b2c340bf65a7              1
# 13  0008288aa423d2a3f00fcb17cd7d8719              1
# 14  0008288aa423d2a3f00fcb17cd7d8719              2
#
#                           product_id                         seller_id  \
# ...

# %%
df.tail(15) # imprime as últimas 15 linhas do df
# Out:
#                                 order_id  order_item_id  \
# 112635  fff8287bbae429a99bb7e8c21d151c41              2
# 112636  fff90cdcb3b2e6cfb397d05d562fd3fe              1
# 112637  fffa82886406ccf10c7b4e35c4ff2788              1
# 112638  fffb0b1a50e65c449020434fa835e078              1
# 112639  fffb2ef8874127f75b52b643880fd7e0              1
# 112640  fffb9224b6fc7c43ebb0904318b10b5f              1
# 112641  fffb9224b6fc7c43ebb0904318b10b5f              2
# 112642  fffb9224b6fc7c43ebb0904318b10b5f              3
# 112643  fffb9224b6fc7c43ebb0904318b10b5f              4
# 112644  fffbee3b5462987e66fb49b1c5411df2              1
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
# ...

# %%
df[112639:112649] # imprime as linhas presentes entre 112639 e 112649
# Out:
#                                 order_id  order_item_id  \
# 112639  fffb2ef8874127f75b52b643880fd7e0              1
# 112640  fffb9224b6fc7c43ebb0904318b10b5f              1
# 112641  fffb9224b6fc7c43ebb0904318b10b5f              2
# 112642  fffb9224b6fc7c43ebb0904318b10b5f              3
# 112643  fffb9224b6fc7c43ebb0904318b10b5f              4
# 112644  fffbee3b5462987e66fb49b1c5411df2              1
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
#
#                               product_id                         seller_id  \
# 112639  ebceb9726cf5c6187b48e17fe58747b0  609e1a9a6c2539919b8205cf7c4e6ff0
# 112640  43423cdffde7fda63d0414ed38c11a73  b1fc4f64df5a0e8b6913ab38803c57a9
# 112641  43423cdffde7fda63d0414ed38c11a73  b1fc4f64df5a0e8b6913ab38803c57a9
# ...

# %%
df.sort_values(by='price') # classifique pelos valores levando em consideração a coluna price
# Out:
#                                 order_id  order_item_id  \
# 27652   3ee6513ae7ea23bdfab5b9ab60bffcb5              1
# 87081   c5bdd8ef3c0ec420232e668302179113              2
# 48625   6e864b3f0ec71031117ad4cf46b7f2a1              1
# 57297   8272b63d03f5f79c56e9e4120aec44ef              1
# 57302   8272b63d03f5f79c56e9e4120aec44ef              6
# ...                                  ...            ...
# 11249   199af31afc78c699f0dbf71fb178d4d4              1
# 74336   a96610ab360d42a2e5335a3998b4718a              1
# 107841  f5136e38d1a14a4dbd87dff67da82701              1
# 112233  fefacc66af859508bf1a7934eab1e97f              1
# 3556    0812eb902a67711a1cb742b3cdaa65ae              1
#
#                               product_id                         seller_id  \
# 27652   8a3254bee785a526d548a81a9bc3c9be  96804ea39d96eb908e7c3afdb671bb9e
# 87081   8a3254bee785a526d548a81a9bc3c9be  96804ea39d96eb908e7c3afdb671bb9e
# ...

# %%
df['price'].corr(df['freight_value']) # imprime a correlaçao entre a coluna preço e freight_value
# Out:
# 0.4142043103630356

# %%
df.loc[:,["price"]] #imprime a coluna "price" de forma ordenada
# Out:
#          price
# 0        58.90
# 1       239.90
# 2       199.00
# 3        12.99
# 4       199.90
# ...        ...
# 112645  299.99
# 112646  350.00
# 112647   99.90
# 112648   55.99
# 112649   43.00
#
# [112650 rows x 1 columns]

# %%
df.loc[:,["freight_value"]] #imprime a coluna "freigh_value" de forma ordenada
# Out:
#         freight_value
# 0               13.29
# 1               19.93
# 2               17.87
# 3               12.79
# 4               18.14
# ...               ...
# 112645          43.41
# 112646          36.53
# 112647          16.95
# 112648           8.72
# 112649          12.79
#
# [112650 rows x 1 columns]

# %%
df.sort_values(by='price')  #classificar pelso valores de acordo com a coluna price
# Out:
#                                 order_id  order_item_id  \
# 27652   3ee6513ae7ea23bdfab5b9ab60bffcb5              1
# 87081   c5bdd8ef3c0ec420232e668302179113              2
# 48625   6e864b3f0ec71031117ad4cf46b7f2a1              1
# 57297   8272b63d03f5f79c56e9e4120aec44ef              1
# 57302   8272b63d03f5f79c56e9e4120aec44ef              6
# ...                                  ...            ...
# 11249   199af31afc78c699f0dbf71fb178d4d4              1
# 74336   a96610ab360d42a2e5335a3998b4718a              1
# 107841  f5136e38d1a14a4dbd87dff67da82701              1
# 112233  fefacc66af859508bf1a7934eab1e97f              1
# 3556    0812eb902a67711a1cb742b3cdaa65ae              1
#
#                               product_id                         seller_id  \
# 27652   8a3254bee785a526d548a81a9bc3c9be  96804ea39d96eb908e7c3afdb671bb9e
# 87081   8a3254bee785a526d548a81a9bc3c9be  96804ea39d96eb908e7c3afdb671bb9e
# ...

# %%
df.loc[:,["freight_value","price"]] #imprime as colunas de frete e preço
# Out:
#         freight_value   price
# 0               13.29   58.90
# 1               19.93  239.90
# 2               17.87  199.00
# 3               12.79   12.99
# 4               18.14  199.90
# ...               ...     ...
# 112645          43.41  299.99
# 112646          36.53  350.00
# 112647          16.95   99.90
# 112648           8.72   55.99
# 112649          12.79   43.00
#
# [112650 rows x 2 columns]

# %%
df.iloc[112649] # imprime todos os dados presentes no numero selecionado
# Out:
# order_id               fffe41c64501cc87c801fd61db3f6244
# order_item_id                                         1
# product_id             350688d9dc1e75ff97be326363655e01
# seller_id              f7ccf836d21b2fb1de37564105216cc1
# shipping_limit_date                 2018-06-12 17:10:13
# price                                              43.0
# freight_value                                     12.79
# Name: 112649, dtype: object

# %%
df.iloc[0] # imprime todos os dados presentes no numero selecionado
# Out:
# order_id               00010242fe8c5a6d1ba2dd792cb16214
# order_item_id                                         1
# product_id             4244733e06e7ecb4970a6e2683c13e61
# seller_id              48436dade18ac8b2bce089ec2a041202
# shipping_limit_date                 2017-09-19 09:45:35
# price                                              58.9
# freight_value                                     13.29
# Name: 0, dtype: object

# %%
df.iloc[:,0:7] # imprime valores com as colunas de 0 a 7
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df.price.max() #imprime o valor do produto mais caro presente no dataset
# Out:
# 6735.0

# %%
df.price.min() #imprime o valor do produto mais barato do dataset
# Out:
# 0.85

# %%
df.freight_value.min()
# Out:
# 0.0

# %%
df.freight_value.max() # imprime o valor mais caro de frete
# Out:
# 409.68

# %%
df['price'].value_counts() # retorna as entradas únicas nessa coluna e a quantidade de vezes que se repete
#Esse comando tambem imprime a quantdade que um valor se repete , o que podemos entender como ticket médio do dataframe
# Out:
# 59.90      2481
# 69.90      1987
# 49.90      1953
# 89.90      1548
# 99.90      1432
#            ...
# 1369.90       1
# 108.24        1
# 1224.99       1
# 24.52         1
# 736.00        1
# Name: price, Length: 5968, dtype: int64

# %%
df['freight_value'].value_counts() # retorna as entradas únicas nessa coluna e a quantidade de vezes que se repete
# Out:
# 15.10    3707
# 7.78     2262
# 14.10    1875
# 11.85    1846
# 18.23    1575
#          ...
# 57.83       1
# 80.47       1
# 70.92       1
# 42.85       1
# 6.37        1
# Name: freight_value, Length: 6999, dtype: int64

# %%
df['price'].value_counts(normalize=True) # imprime a porcentagem ou frequencias relativas dos valores exclusivos
# Out:
# 59.90      0.022024
# 69.90      0.017639
# 49.90      0.017337
# 89.90      0.013742
# 99.90      0.012712
#              ...
# 1369.90    0.000009
# 108.24     0.000009
# 1224.99    0.000009
# 24.52      0.000009
# 736.00     0.000009
# Name: price, Length: 5968, dtype: float64

# %%
df[["freight_value","price"]].apply(lambda x: x.max()) # A função imprime os valores máximos para frete e preço
# Out:
# freight_value     409.68
# price            6735.00
# dtype: float64

# %%
df.sort_values(by='price',ascending=True) # ordena o df de acordo com a coluna selecionada, nesse caso a coluna price
# Out:
#                                 order_id  order_item_id  \
# 27652   3ee6513ae7ea23bdfab5b9ab60bffcb5              1
# 87081   c5bdd8ef3c0ec420232e668302179113              2
# 48625   6e864b3f0ec71031117ad4cf46b7f2a1              1
# 57297   8272b63d03f5f79c56e9e4120aec44ef              1
# 57302   8272b63d03f5f79c56e9e4120aec44ef              6
# ...                                  ...            ...
# 11249   199af31afc78c699f0dbf71fb178d4d4              1
# 74336   a96610ab360d42a2e5335a3998b4718a              1
# 107841  f5136e38d1a14a4dbd87dff67da82701              1
# 112233  fefacc66af859508bf1a7934eab1e97f              1
# 3556    0812eb902a67711a1cb742b3cdaa65ae              1
#
#                               product_id                         seller_id  \
# 27652   8a3254bee785a526d548a81a9bc3c9be  96804ea39d96eb908e7c3afdb671bb9e
# 87081   8a3254bee785a526d548a81a9bc3c9be  96804ea39d96eb908e7c3afdb671bb9e
# ...

# %%
df.sort_values(by='freight_value',ascending=True)
# Out:
#                                order_id  order_item_id  \
# 81475  b925a62bfdf14b152f2fb572d1aa672c              1
# 47406  6bc5da0239ae806987a22ccbb45f3fc8              1
# 51117  742cbcd370fd2e637bf3f2570ac5ed2a              1
# 15225  22b1eef278d4416c1e867a55d1c39fea              1
# 94446  d62387acb3914789e712406e9882e549              1
# ...                                 ...            ...
# 16731  264a7e199467906c0727394df82d1a6a              1
# 69797  9f49bd16053df810384e793386312674              1
# 28044  3fde74c28a3d5d618c00f26d51baafa0              1
# 3303   076d1555fb53a89b0ef4d529e527a0f6              1
# 73486  a77e1550db865202c56b19ddc6dc4d53              1
#
#                              product_id                         seller_id  \
# 81475  53b36df67ebb7c41585e8d54d6772e08  7d13fca15225358621be4086e1eb0964
# 47406  53b36df67ebb7c41585e8d54d6772e08  4869f7a5dfa277a7dca6462dcf3b52b2
# 51117  aca2eb7d00ea1a7b8ebd4e68314663af  955fee9216a65b617aa5c0531780ce60
# ...

# %%
import pandas as pd

# %%
sns.factorplot("price", "freight_value", data=df, palette="BuPu_d") 
# Imprime um gráfico que demonstra a relação diretamente proporcional entre o preço das compras e o valor do frete.
# Out:
# c:\Users\s145n\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# c:\Users\s145n\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
